# %% [markdown]
# # Initial analysis

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# Reading netCDF files

# %%
# Load a NetCDF file
ds = xr.open_mfdataset("era5_data.nc")
print(ds)

# %%
# Plot a temperature time series
plt.plot(df["date"], df["pp"])
plt.xlabel("Date")
plt.ylabel("Precitation")
plt.title("Precitation Over Time")
plt.show()
