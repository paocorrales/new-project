# %% [markdown]
# # Initial analysis

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# Reading netCDF files

# %%
# Load a NetCDF file
ds = xr.open_mfdataset("era5_data.nc")
print(ds)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load a NetCDF file
# ----> 2 ds = xr.open_mfdataset("era5_data.nc")
#       3 print(ds)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/xarray/backends/api.py:1541, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1538 paths = _find_absolute_paths(paths, engine=engine, **kwargs)
#    1540 if not paths:
# -> 1541     raise OSError("no files to open")
#    1543 paths1d: list[str | ReadBuffer]
#    1544 if combine == "nested":
#
# OSError: no files to open

# %%
# Plot a temperature time series
plt.plot(df["date"], df["pp"])
plt.xlabel("Date")
plt.ylabel("Precipitation")
plt.title("Temperature Over Time")
plt.show()
